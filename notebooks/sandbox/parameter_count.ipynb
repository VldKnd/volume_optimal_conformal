# %%
from utils.parameters_count import count_trainable_parameters_from_config

from configs.predictors.rearranged_transport import DenseRearrangedTransportPredictorConfig

# %%
config = DenseRearrangedTransportPredictorConfig(
    x_dim=1,
    y_dim=2,
    hidden_dimension=64,
    number_of_hidden_layers=5,
    use_adjoint=False,
    method="euler",
    number_of_steps=16,
    seed=1,
    device="cpu",
    dtype="float32",
)

count_trainable_parameters_from_config(config)
# Out:
# 21185
