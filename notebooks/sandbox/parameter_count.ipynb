# %%
from utils.parameters_count import count_trainable_parameters_from_config

from configs.predictors.rearranged_transport import RearrangedTransportPredictorConfig
from configs.predictors.transport import ConvexPotentialFlowPredictorConfig

# %%
config = ConvexPotentialFlowPredictorConfig(
    x_dim=1,
    y_dim=2,
    hidden_dim=8,
    num_hidden_layers=2,
    num_blocks=5,
    inverse_lr=1.,
    inverse_max_iter=10000,
    seed=1,
    device='cpu',
    dtype='float',
)

count_trainable_parameters_from_config(config)
# Out:
# 2274
