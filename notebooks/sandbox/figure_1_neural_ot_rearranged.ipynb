# %% [markdown]
# # Figure 1: Neural OT rearrangement on the banana target
#
# This notebook trains a neural OT map and a dense rearrangement of that map. The final cell plots only target-space contours: the neural OT pushforward of a latent ball, the rearranged neural OT pushforward of the same ball, and the oracle HDR contour obtained by pushing that ball through the dataset operator.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np
import torch
from scipy.stats import chi2

repo_root = Path.cwd()
if not (repo_root / "src").exists():
    repo_root = repo_root.parent.parent

src_path = str(repo_root / "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

from configs.datasets.synthetic.banana_dataset import BananaDatasetConfig
from configs.predictors.rearranged_transport import (
    RearrangedTransportPredictorConfig,
)
from configs.predictors.transport.neural_optimal_transport import (
    NeuralOptimalTransportPredictorConfig,
)
from configs.trainers.rearranged_transport import (
    RearrangedTransportTrainerConfig,
)
from configs.trainers.transport.neural_optimal_transport import (
    NeuralOptimalTransportTrainerConfig,
)
from data.datasets.synthetic.banana_dataset import BananaDataset
from data.loaders import make_xy_dataloader
from predictors.rearranged_transport import RearrangedTransportPredictor
from predictors.transport.neural_optimal_transport import NeuralOptimalTransportPredictor
from trainers.rearranged_transport import RearrangedTransportTrainer
from trainers.transport.neural_optimal_transport import NeuralOptimalTransportTrainer

plt.rcParams.update({
    "figure.dpi": 140,
    "savefig.dpi": 300,
    "axes.spines.top": False,
    "axes.spines.right": False,
})

# %%
seed = 7
torch.manual_seed(seed)
np.random.seed(seed)

device = "cpu"
dtype = "float32"

n_train = 100_000
n_calibration = 1_024
n_test = 1_024
batch_size = 256

coverage_mass = 0.75
x_plot_value = 2.3

ot_epochs = 50
ot_warmup_iterations = 10
c_transform_max_iter = 1000

rearrangement_epochs = 500

n_boundary_points = 720
plot_batch_size = 256

output_path = Path("../figures/figure_1_neural_ot_rearranged.pdf")
output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
dataset_config = BananaDatasetConfig(
    n_train=n_train,
    n_calibration=n_calibration,
    n_test=n_test,
    x_dim=1,
    y_dim=2,
    seed=seed,
    device=device,
    dtype=dtype,
)

dataset = BananaDataset(dataset_config)
splits = dataset.get_splits()

train_dataloader = make_xy_dataloader(
    data=splits.train,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

print("train x/y:", splits.train.x.shape, splits.train.y.shape)
print("calibration x/y:", splits.calibration.x.shape, splits.calibration.y.shape)
print("test x/y:", splits.test.x.shape, splits.test.y.shape)
# Out:
# train x/y: torch.Size([100000, 1]) torch.Size([100000, 2])
# calibration x/y: torch.Size([1024, 1]) torch.Size([1024, 2])
# test x/y: torch.Size([1024, 1]) torch.Size([1024, 2])

# %%
predictor_config = NeuralOptimalTransportPredictorConfig(
    x_dim=dataset.x_dim,
    y_dim=dataset.y_dim,
    hidden_dim=64,
    num_hidden_layers=8,
    potential_type="u",
    c_transform_lr=1.,
    c_transform_max_iter=c_transform_max_iter,
    seed=seed,
    device=device,
    dtype=dtype,
)

trainer_config = NeuralOptimalTransportTrainerConfig(
    epochs=ot_epochs,
    learning_rate=1e-3,
    weight_decay=1e-4,
    warmup_iterations=ot_warmup_iterations,
    grad_clip_norm=1.0,
    use_cosine_scheduler=True,
    verbose=True,
)

predictor = NeuralOptimalTransportPredictor(predictor_config)
trainer = NeuralOptimalTransportTrainer(trainer_config)

predictor = trainer.fit(
    predictor=predictor,
    dataloader=train_dataloader,
)
predictor.eval()

trainer.training_history[-5:]
# Out:
# Warmup 10 | Loss 0.0153: 100%|██████████| 10/10 [00:34<00:00,  3.48s/it]
# Epoch 2 | Potential loss 1.2321:   4%|▍         | 2/50 [00:58<23:32, 29.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 27
#      23
#      24 predictor = NeuralOptimalTransportPredictor(predictor_config)
#      25 trainer = NeuralOptimalTransportTrainer(trainer_config)
#      26
# ---> 27 predictor = trainer.fit(
#      28     predictor=predictor,
#      29     dataloader=train_dataloader,
#      30 )
#
# File ~/minimal_volume_conformal_prediction/src/trainers/transport/neural_optimal_transport.py:100, in NeuralOptimalTransportTrainer.fit(self, predictor, dataloader)
#      93 loss.backward()
#      95 torch.nn.utils.clip_grad_norm_(
#      96     predictor.potential_network.parameters(),
#      97     max_norm=self.config.grad_clip_norm,
#      98 )
# --> 100 optimizer.step()
#     102 if scheduler is not None:
#     103     scheduler.step()
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/lr_scheduler.py:166, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     164 opt = opt_ref()
#     165 opt._opt_called = True  # type: ignore[union-attr]
# --> 166 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/optimizer.py:530, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     525             raise RuntimeError(
#     526                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     527             )
#     529 # pyrefly: ignore [invalid-param-spec]
# --> 530 out = func(*args, **kwargs)
#     531 self._optimizer_step_code()
#     533 # call optimizer step post hooks
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/optimizer.py:80, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      78     torch.set_grad_enabled(self.defaults["differentiable"])
#      79     torch._dynamo.graph_break()
# ---> 80     ret = func(*args, **kwargs)
#      81 finally:
#      82     torch._dynamo.graph_break()
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/optimizer.py:148, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     146     return disabled_func(*args, **kwargs)
#     147 else:
# --> 148     return func(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/optim/adam.py:544, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     542         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     543     else:
# --> 544         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     546     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     548 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
rearranged_predictor_config = RearrangedTransportPredictorConfig(
    x_dim=dataset.x_dim,
    y_dim=dataset.y_dim,
    hidden_dimension=16,
    number_of_hidden_layers=4,
    use_adjoint=False,
    method="rk4",
    number_of_steps=16,
    seed=seed,
    device=device,
    dtype=dtype,
)

rearranged_predictor = RearrangedTransportPredictor(
    config=rearranged_predictor_config,
    transport_predictor=predictor,
)

rearranged_trainer_config = RearrangedTransportTrainerConfig(
    epochs=100,
    alpha=coverage_mass,
    train_transport_map=False,
    learning_rate=1e-3,
    weight_decay=1e-4,
    grad_clip_norm=1.0,
    use_cosine_scheduler=True,
    verbose=True,
)

rearranged_trainer = RearrangedTransportTrainer(rearranged_trainer_config)
rearranged_predictor = rearranged_trainer.fit(
    predictor=rearranged_predictor,
    dataloader=train_dataloader,
)
rearranged_predictor.eval()

rearranged_trainer.training_history[-5:]
# Out:
# Epoch 63 | Log-volume -0.0136:  63%|██████▎   | 63/100 [47:24<27:50, 45.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 31
#      27     verbose=True,
#      28 )
#      29
#      30 rearranged_trainer = RearrangedTransportTrainer(rearranged_trainer_config)
# ---> 31 rearranged_predictor = rearranged_trainer.fit(
#      32     predictor=rearranged_predictor,
#      33     dataloader=train_dataloader,
#      34 )
#
# File ~/minimal_volume_conformal_prediction/src/trainers/rearranged_transport/dense.py:91, in RearrangedTransportTrainer.fit(self, predictor, dataloader, transport_trainer)
#      79 x = self._repeat_context(
#      80     x=x_batch,
#      81     mc_samples_per_x=self.config.mc_samples_per_x,
#      82 )
#      83 u = self._sample_uniform_ball(
#      84     batch_size=x.shape[0],
#      85     dimension=predictor.y_dim,
#    (...)     88     dtype=predictor.dtype,
#      89 )
# ---> 91 loss = self.estimate_log_volume(
#      92     predictor=predictor,
#      93     x=x,
#      94     u=u,
#      95 )
#      97 if not torch.isfinite(loss):
#      98     raise FloatingPointError(
#      99         "Non-finite rearranged transport loss."
#     100     )
#
# File ~/minimal_volume_conformal_prediction/src/trainers/rearranged_transport/dense.py:145, in RearrangedTransportTrainer.estimate_log_volume(self, predictor, x, u)
#     139 def estimate_log_volume(
#     140     self,
#     141     predictor: RearrangedTransportPredictor,
#     142     x: torch.Tensor,
#     143     u: torch.Tensor,
#     144 ) -> torch.Tensor:
# --> 145     weights = predictor.log_det(
#     146         x=x,
#     147         u=u,
#     148     )
#     150     return torch.logsumexp(weights, dim=0) - math.log(weights.numel())
#
# File ~/minimal_volume_conformal_prediction/src/predictors/rearranged_transport/dense.py:157, in RearrangedTransportPredictor.log_det(self, x, u)
#     149 def log_det(
#     150     self,
#     151     x: torch.Tensor,
#     152     u: torch.Tensor,
#     153 ) -> torch.Tensor:
#     154     """
#     155     log |det D_u (T_x o S_x)(u)|.
#     156     """
# --> 157     rearranged_u = self.rearrangement_pushforward(x=x, u=u)
#     158     return self.transport_log_det(
#     159         x=x,
#     160         u=rearranged_u,
#    (...)    163         rearranged_u=rearranged_u,
#     164     )
#
# File ~/minimal_volume_conformal_prediction/src/predictors/rearranged_transport/dense.py:102, in RearrangedTransportPredictor.rearrangement_pushforward(self, x, u)
#     100 x = self.to_device(x)
#     101 u = self.to_device(u)
# --> 102 return self.rearrangement_flow.forward(u=u, x=x, end_time=1.0)
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/flow_integration.py:182, in VectorFieldFlow.forward(self, u, x, end_time)
#     179     end_time = float(end_time)
#     180     self.last_end_time = end_time
# --> 182 return self.integrate(u, x=x, start_time=0.0, end_time=end_time)
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/flow_integration.py:150, in VectorFieldFlow.integrate(self, u, x, start_time, end_time)
#     144 def ode_function(
#     145     t: torch.Tensor,
#     146     state: torch.Tensor,
#     147 ) -> torch.Tensor:
#     148     return self.vector_field(state, context, t)
# --> 150 solution = solver(
#     151     ode_function,
#     152     u,
#     153     times,
#     154     **solver_kwargs,
#     155 )
#     156 return solution[-1]
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torchdiffeq/_impl/odeint.py:80, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      77 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      79 if event_fn is None:
# ---> 80     solution = solver.integrate(t)
#      81 else:
#      82     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torchdiffeq/_impl/solvers.py:114, in FixedGridODESolver.integrate(self, t)
#     112 dt = t1 - t0
#     113 self.func.callback_step(t0, y0, dt)
# --> 114 dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     115 y1 = y0 + dy
#     117 while j < len(t) and t1 >= t[j]:
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torchdiffeq/_impl/fixed_grid.py:29, in RK4._step_func(self, func, t0, dt, t1, y0)
#      27 def _step_func(self, func, t0, dt, t1, y0):
#      28     f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
# ---> 29     return rk4_alt_step_func(func, t0, dt, t1, y0, f0=f0, perturb=self.perturb), f0
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torchdiffeq/_impl/rk_common.py:113, in rk4_alt_step_func(func, t0, dt, t1, y0, f0, perturb)
#     111 if k1 is None:
#     112     k1 = func(t0, y0, perturb=Perturb.NEXT if perturb else Perturb.NONE)
# --> 113 k2 = func(t0 + dt * _one_third, y0 + dt * k1 * _one_third)
#     114 k3 = func(t0 + dt * _two_thirds, y0 + dt * (k2 - k1 * _one_third))
#     115 k4 = func(t1, y0 + dt * (k1 - k2 + k3), perturb=Perturb.PREV if perturb else Perturb.NONE)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torchdiffeq/_impl/misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/flow_integration.py:148, in VectorFieldFlow.integrate.<locals>.ode_function(t, state)
#     144 def ode_function(
#     145     t: torch.Tensor,
#     146     state: torch.Tensor,
#     147 ) -> torch.Tensor:
# --> 148     return self.vector_field(state, context, t)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/dense_skew_symmetric_vector_field.py:210, in DenseGaussianSkewVectorField.forward(self, u, x, t)
#     203 def forward(
#     204     self,
#     205     u: torch.Tensor,
#     206     x: torch.Tensor | None = None,
#     207     t: torch.Tensor | float | None = None,
#     208 ) -> torch.Tensor:
#     209     with torch.enable_grad():
# --> 210         return self.calculate_exact_velocity_field(u=u, x=x, t=t)
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/dense_skew_symmetric_vector_field.py:198, in DenseGaussianSkewVectorField.calculate_exact_velocity_field(self, u, x, t)
#     189 context = self._prepare_context(u=u, x=x).reshape(
#     190     number_of_points,
#     191     self.context_dimension,
#     192 )
#     193 time = self._prepare_time(u=u, t=t).reshape(
#     194     number_of_points,
#     195     int(self.time_dependent),
#     196 )
# --> 198 velocity = torch.func.vmap(self.calculate_single_input_exact_velocity_field,
#     199                            )(u_flat, context, time)
#     201 return velocity.reshape(*batch_shape, self.dimension)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/apis.py:246, in vmap.<locals>.wrapped(*args, **kwargs)
#     244 def wrapped(*args: _P.args, **kwargs: _P.kwargs) -> _R:
#     245     # pyrefly: ignore[bad-argument-type]
# --> 246     return vmap_impl(
#     247         # pyrefly: ignore[bad-argument-type]
#     248         func,
#     249         in_dims,
#     250         out_dims,
#     251         randomness,
#     252         chunk_size,
#     253         *args,
#     254         **kwargs,
#     255     )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/vmap.py:316, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     305     return _chunked_vmap(
#     306         func,
#     307         flat_in_dims,
#    (...)    312         **kwargs,
#     313     )
#     315 # If chunk_size is not specified.
# --> 316 return _flat_vmap(
#     317     func,
#     318     batch_size,
#     319     flat_in_dims,
#     320     flat_args,
#     321     args_spec,
#     322     out_dims,
#     323     randomness,
#     324     **kwargs,
#     325 )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/vmap.py:507, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     503 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     504     batched_inputs = _create_batched_inputs(
#     505         flat_in_dims, flat_args, vmap_level, args_spec
#     506     )
# --> 507     batched_outputs = func(*batched_inputs, **kwargs)
#     508     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/dense_skew_symmetric_vector_field.py:169, in DenseGaussianSkewVectorField.calculate_single_input_exact_velocity_field(self, u, x, t)
#     163 def calculate_single_input_exact_velocity_field(
#     164     self,
#     165     u: torch.Tensor,
#     166     x: torch.Tensor,
#     167     t: torch.Tensor | float | None,
#     168 ) -> torch.Tensor:
# --> 169     jacobian_matrix, skew_matrix = torch.func.jacfwd(
#     170         func=self.calculate_single_input_skew_symmetric_matrix,
#     171         has_aux=True,
#     172         argnums=0,
#     173     )(u, x, t)
#     175     divergence = jacobian_matrix.diagonal(dim1=1, dim2=2).sum(-1)
#     176     return divergence - skew_matrix @ u
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/eager_transforms.py:1389, in jacfwd.<locals>.wrapper_fn(*args)
#    1386     _, jvp_out = output  # pyrefly: ignore[bad-unpacking]
#    1387     return jvp_out
# -> 1389 results = vmap(push_jvp, randomness=randomness)(basis)
#    1390 aux: Any = None
#    1391 if has_aux:
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/apis.py:246, in vmap.<locals>.wrapped(*args, **kwargs)
#     244 def wrapped(*args: _P.args, **kwargs: _P.kwargs) -> _R:
#     245     # pyrefly: ignore[bad-argument-type]
# --> 246     return vmap_impl(
#     247         # pyrefly: ignore[bad-argument-type]
#     248         func,
#     249         in_dims,
#     250         out_dims,
#     251         randomness,
#     252         chunk_size,
#     253         *args,
#     254         **kwargs,
#     255     )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/vmap.py:316, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     305     return _chunked_vmap(
#     306         func,
#     307         flat_in_dims,
#    (...)    312         **kwargs,
#     313     )
#     315 # If chunk_size is not specified.
# --> 316 return _flat_vmap(
#     317     func,
#     318     batch_size,
#     319     flat_in_dims,
#     320     flat_args,
#     321     args_spec,
#     322     out_dims,
#     323     randomness,
#     324     **kwargs,
#     325 )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/vmap.py:507, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     503 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     504     batched_inputs = _create_batched_inputs(
#     505         flat_in_dims, flat_args, vmap_level, args_spec
#     506     )
# --> 507     batched_outputs = func(*batched_inputs, **kwargs)
#     508     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/eager_transforms.py:1378, in jacfwd.<locals>.wrapper_fn.<locals>.push_jvp(basis)
#    1377 def push_jvp(basis: Any) -> Any:
# -> 1378     output = _jvp_with_argnums(
#    1379         func, args, basis, argnums=argnums, has_aux=has_aux
#    1380     )
#    1381     # output[0] is the output of `func(*args)`
#    1382     error_if_complex("jacfwd", output[0], is_input=False)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_functorch/eager_transforms.py:1211, in _jvp_with_argnums(func, primals, tangents, argnums, strict, has_aux)
#    1209     primals = _wrap_all_tensors(primals, level)
#    1210     duals = _replace_args(primals, duals, argnums)
# -> 1211 result_duals = func(*duals)
#    1212 aux: Any = None
#    1213 if has_aux:
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/dense_skew_symmetric_vector_field.py:156, in DenseGaussianSkewVectorField.calculate_single_input_skew_symmetric_matrix(self, u, x, t)
#     150 def calculate_single_input_skew_symmetric_matrix(
#     151     self,
#     152     u: torch.Tensor,
#     153     x: torch.Tensor,
#     154     t: torch.Tensor | float | None,
#     155 ) -> tuple[torch.Tensor, torch.Tensor]:
# --> 156     skew_matrix = self.calculate_skew_symmetric_matrix(
#     157         u=u,
#     158         x=x,
#     159         t=t,
#     160     )
#     161     return skew_matrix, skew_matrix
#
# File ~/minimal_volume_conformal_prediction/src/networks/measure_preserving_flows/dense_skew_symmetric_vector_field.py:126, in DenseGaussianSkewVectorField.calculate_skew_symmetric_matrix(self, u, x, t)
#     123 context = self._prepare_context(u=u, x=x)
#     124 time = self._prepare_time(u=u, t=t)
# --> 126 raw_entries = self.network(
#     127     state=u,
#     128     x=context,
#     129     t=time,
#     130 )
#     132 upper_flat = raw_entries.new_zeros(
#     133     (*raw_entries.shape[:-1], self.dimension * self.dimension)
#     134 ).scatter(
#    (...)    140     src=raw_entries,
#     141 )
#     142 upper_matrix = upper_flat.reshape(
#     143     *raw_entries.shape[:-1],
#     144     self.dimension,
#     145     self.dimension,
#     146 )
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/minimal_volume_conformal_prediction/src/networks/mlp_vector_field.py:66, in MLPVectorField.forward(self, state, x, t)
#      60 def forward(
#      61     self,
#      62     state: torch.Tensor,
#      63     x: torch.Tensor,
#      64     t: torch.Tensor,
#      65 ) -> torch.Tensor:
# ---> 66     return self.net(torch.cat([state, x, self._time_feature(state, t)], dim=-1))
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# File ~/minimal_volume_conformal_prediction/.venv/lib/python3.13/site-packages/torch/_prims_common/wrappers.py:291, in out_wrapper.<locals>._out_wrapper.<locals>._fn(*args, **kwargs)
#     288 factory_kwargs = ("device", "dtype")
#     289 is_factory_fn = all(p in sig.parameters for p in factory_kwargs)
# --> 291 @wraps(fn)
#     292 def _fn(*args: _P.args, **kwargs: _P.kwargs):
#     293     out = kwargs.pop("out", None)
#     294     if is_factory_fn and out is not None:
#
# KeyboardInterrupt:

# %%
plt.plot([epoch['log_volume_loss'] for epoch in rearranged_trainer.training_history])

# %%
def circle_boundary(radius, n_points):
    theta = np.linspace(0.0, 2.0 * np.pi, n_points, endpoint=False)
    boundary = np.column_stack([np.cos(theta), np.sin(theta)]) * radius
    return torch.as_tensor(boundary, device=dataset.device, dtype=dataset.dtype)


def close_contour(contour):
    contour = np.asarray(contour)
    if np.allclose(contour[0], contour[-1]):
        return contour
    return np.vstack([contour, contour[0]])


def repeated_x(batch_size, x_value=1.1):
    return torch.full(
        (batch_size, dataset.x_dim),
        fill_value=x_value,
        device=dataset.device,
        dtype=dataset.dtype,
    )


def model_pushforward_contour(model, u, batch_size=plot_batch_size):
    mapped = []
    for start in range(0, u.shape[0], batch_size):
        u_batch = u[start:start + batch_size]
        x_batch = repeated_x(u_batch.shape[0]).to(u_batch)
        y_batch = model.pushforward(x=x_batch, u=u_batch)
        mapped.append(y_batch.detach().cpu())
    return close_contour(torch.cat(mapped, dim=0).numpy())


def oracle_pushforward_contour(u, batch_size=plot_batch_size):
    mapped = []
    for start in range(0, u.shape[0], batch_size):
        u_batch = u[start:start + batch_size]
        x_batch = repeated_x(u_batch.shape[0]).to(u_batch)
        y_batch = dataset.push_u_given_x(u=u_batch, x=x_batch)
        mapped.append(y_batch.detach().cpu())
    return close_contour(torch.cat(mapped, dim=0).numpy())


def contour_bounds(contours, side_margin=0.05, bottom_margin=0.10, top_margin=0.20):
    points = np.vstack([np.asarray(contour) for contour in contours])
    xmin, ymin = points.min(axis=0)
    xmax, ymax = points.max(axis=0)
    width = max(xmax - xmin, 1e-12)
    height = max(ymax - ymin, 1e-12)
    return (
        xmin - side_margin * width,
        xmax + side_margin * width,
        ymin - bottom_margin * height,
        ymax + top_margin * height,
    )

# %%
r_source = float(np.sqrt(chi2.ppf(coverage_mass, df=dataset.y_dim)))
source_ball_boundary = circle_boundary(
    radius=r_source,
    n_points=n_boundary_points,
)

neural_ot_contour = model_pushforward_contour(predictor, source_ball_boundary)
rearranged_contour = model_pushforward_contour(
    rearranged_predictor,
    source_ball_boundary,
)
oracle_hdr_contour = oracle_pushforward_contour(source_ball_boundary)

xmin, xmax, ymin, ymax = contour_bounds([
    neural_ot_contour,
    rearranged_contour,
    oracle_hdr_contour,
])

print(f"coverage_mass = {coverage_mass:.3f}")
print(f"x = {x_plot_value:.3f}")
print(f"source radius = {r_source:.4f}")

fig, ax = plt.subplots(figsize=(5.8, 4.8), constrained_layout=True)

ax.plot(
    neural_ot_contour[:, 0],
    neural_ot_contour[:, 1],
    color="forestgreen",
    linewidth=2.0,
    label="Neural OT",
)
ax.plot(
    rearranged_contour[:, 0],
    rearranged_contour[:, 1],
    color="royalblue",
    linewidth=2.0,
    label="Rearranged Neural OT",
)
ax.plot(
    oracle_hdr_contour[:, 0],
    oracle_hdr_contour[:, 1],
    color="darkorange",
    linewidth=2.0,
    label="Oracle HDR",
)

ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
ax.set_aspect("equal", adjustable="box")
ax.set_xlabel(r"$y_1$")
ax.set_ylabel(r"$y_2$")
ax.set_title(
    rf"Pushforward contours at $x={x_plot_value:.1f}$, mass={coverage_mass:.2f}"
)
ax.legend(frameon=False, loc="upper right")

fig.savefig(
    output_path,
    format="pdf",
    bbox_inches="tight",
    pad_inches=0.02,
    metadata={"Creator": "Matplotlib"},
)

plt.show()
# Out:
# coverage_mass = 0.250
# x = 2.300
# source radius = 0.7585

# %%
u = torch.randn(1024, 2)
x = torch.zeros(1024, 1)
u_np = u.detach().numpy()
u_pf_np =  rearranged_predictor.rearrangement_flow.forward(
    u=u,
    x=x,
    end_time=1.
).detach().numpy()


x = torch.zeros(source_ball_boundary.shape[0], 1)

scale_to_pf_boundary = {}
scale_to_sc_boundary = {}
for scale in [0.5, 1., 2., 3., 4., 5., 6.]:
    scaled_source_boundary = source_ball_boundary * scale
    scale_to_sc_boundary[scale] = scaled_source_boundary.numpy()
    scale_to_pf_boundary[scale] = rearranged_predictor.rearrangement_flow.forward(
        u=scaled_source_boundary,
        x=x,
        end_time=1.
    ).detach().numpy()

# %%
plt.scatter(u_np[:, 0], u_np[:, 1])
plt.scatter(u_pf_np[:, 0], u_pf_np[:, 1])
plt.show()

for scale in scale_to_sc_boundary.keys():

    plt.plot(scale_to_sc_boundary[scale][:, 0], scale_to_sc_boundary[scale][:, 1], c="red")
    plt.plot(scale_to_pf_boundary[scale][:, 0], scale_to_pf_boundary[scale][:, 1], c='green')
    
plt.show()
